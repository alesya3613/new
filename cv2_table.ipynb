# %%
import cv2
import numpy as np
import pandas as pd

image = cv2.imread('D:\\5d8a0f1f48fee2d324027b49ba8deae6.jpg')
template = cv2.imread('D:\\1504e15ac7e490bebab30d1e7bfa7901.jpg', cv2.IMREAD_GRAYSCALE)

# %%
def show_pic(image):
    plt.figure(figsize=(10,10))
    plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
    plt.axis('off')  # Отключаем оси координат
    plt.show()

# %%
height, width = image.shape[:2] 
M = cv2.getRotationMatrix2D((width/2, height/2), 45, 1)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)


data = [
    ["Чтение, запись и отображение", "cv2.imread(), cv2.imwrite(), cv2.imshow()", "image = cv2.imread('image.jpg'); cv2.imshow('Image', image); cv2.waitKey(0); cv2.destroyAllWindows()"],
    ["Изменение цветового пространства", "cv2.cvtColor() (например, RGB в Gray, HSV)", "gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)"],
    ["Изменение размера", "cv2.resize()", "resized = cv2.resize(image, (300, 300))"],
    ["Вращение", "cv2.getRotationMatrix2D(), cv2.warpAffine()", "M = cv2.getRotationMatrix2D((width/2, height/2), 45, 1); rotated = cv2.warpAffine(image, M, (width, height))"],
    ["Обрезание", "Индексация массивов NumPy (например, image[100:200, 50:150])", "cropped = image[100:200, 50:150]"],
    ["Пороговая обработка", "cv2.threshold(), cv2.adaptiveThreshold()", "ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)"],
    ["Сглаживание (размытие)", "cv2.blur(), cv2.GaussianBlur(), cv2.medianBlur()", "blurred = cv2.GaussianBlur(image, (5,5), 0)"],
    ["Морфологические операции", "cv2.erode(), cv2.dilate(), cv2.morphologyEx()", "dilated = cv2.dilate(image, None, iterations=2)"],
    ["Градиенты изображения", "cv2.Sobel(), cv2.Laplacian(), cv2.Canny()", "edges = cv2.Canny(image, 100, 200)"],
    ["Обнаружение краев", "cv2.Canny()", "edges = cv2.Canny(image, 50, 150)"],
    ["Обнаружение углов", "cv2.cornerHarris(), cv2.goodFeaturesToTrack()", "corners = cv2.goodFeaturesToTrack(gray, 50, 0.01, 10)"],
    ["Обнаружение объектов по шаблону", "cv2.matchTemplate()", "result = cv2.matchTemplate(image, template, cv2.TM_CCOEFF_NORMED)"],]

# %%
data
# Out:
# [['Чтение, запись и отображение',
#   'cv2.imread(), cv2.imwrite(), cv2.imshow()',
#   "image = cv2.imread('D:\\5d8a0f1f48fee2d324027b49ba8deae6.jpg'); cv2.imshow('Image', image); cv2.waitKey(0); cv2.destroyAllWindows()"],
#  ['Изменение цветового пространства',
#   'cv2.cvtColor() (например, RGB в Gray, HSV)',
#   array([[ 15,  15,  15, ..., 125, 125, 120],
#          [ 18,  18,  18, ..., 126, 129, 126],
#          [ 23,  23,  23, ..., 122, 126, 124],
#          ...,
#          [ 21,  19,  20, ..., 106, 109, 113],
#          [ 16,  18,  29, ...,  96, 101, 105],
#          [ 19,  29,  46, ...,  90,  95, 100]], dtype=uint8)],
#  ['Изменение размера',
#   'cv2.resize()',
#   array([[[  4,  11,  26],
#           [  4,  11,  26],
#           [  4,  11,  26],
#           ...,
#           [ 75, 116, 138],
#           [ 85, 122, 141],
#           [ 83, 121, 139]],
#
#          [[  6,  14,  31],
#           [  6,  14,  31],
#           [  6,  14,  31],
#           ...,
# ...

# %%
import pandas as pd

# Создание DataFrame из данных
df = pd.DataFrame(data, columns=["Возможность OpenCV", "Реализация", "Пример кода"])

# Вывод таблицы (лучше для Jupyter Notebook)
from IPython.display import display
display(df)
# Out:
#                   Возможность OpenCV  \
# 0       Чтение, запись и отображение
# 1   Изменение цветового пространства
# 2                  Изменение размера
# 3                           Вращение
# 4                          Обрезание
# 5                Пороговая обработка
# 6             Сглаживание (размытие)
# 7           Морфологические операции
# 8              Градиенты изображения
# 9                  Обнаружение краев
# 10                 Обнаружение углов
# 11   Обнаружение объектов по шаблону
#
#                                            Реализация  \
# 0           cv2.imread(), cv2.imwrite(), cv2.imshow()
# 1          cv2.cvtColor() (например, RGB в Gray, HSV)
# 2                                        cv2.resize()
# 3         cv2.getRotationMatrix2D(), cv2.warpAffine()
# 4   Индексация массивов NumPy (например, image[100...
# 5            cv2.threshold(), cv2.adaptiveThreshold()
# 6    cv2.blur(), cv2.GaussianBlur(), cv2.medianBlur()
# ...
